# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_excel("C:\\Users\\HP\\Desktop\\research paper\\Quesstionaire\\MM1921438_G.V.S.R.M.SUHASH.xlsx")

# %%
#dataset.head()

# %%
dataset=dataset.drop(columns="Name",axis=1)

# %%
dataset.head()
# Out:
#                 Timestamp Gender    Age Community Type Occupation  \
# 0 2020-06-26 16:04:07.437   Male  26-35          Urban    Student
# 1 2020-06-26 16:11:06.600   Male  15-25          Urban    Student
# 2 2020-06-26 16:13:08.486   Male  15-25          Urban    Student
# 3 2020-06-26 16:13:59.355   Male  15-25       SubUrban    Student
# 4 2020-06-26 16:14:43.435   Male  15-25          Urban    Student
#
#    What is your Educational Background? How frequently do you read the book?  \
# 0                        Postgraduation                           less often
# 1                        Postgraduation                    few times a month
# 2                       Undergraduation                    few times a month
# 3                        Postgraduation                           less often
# 4                       Undergraduation                                never
#
#   Do you read e-book? Which source do you prefer for reading?  \
# ...

# %%
dataset.columns
# Out:
# Index(['Timestamp', 'Gender', 'Age', 'Community Type', 'Occupation',
#        ' What is your Educational Background?',
#        'How frequently do you read the book?', 'Do you read e-book?',
#        'Which source do you prefer for reading?',
#        'who influences to buy an e-book [individual decision]',
#        'who influences to buy an e-book [friends]',
#        'who influences to buy an e-book [relatives]',
#        'who influences to buy an e-book [advertisements]',
#        'which category you falls under [lazy]',
#        'which category you falls under [active]',
#        'which category you falls under [proactive]',
#        'Do you think availability of internet is the reason behind the growth of usage of E-book?',
#        'How likely do you prefer using e-book ?',
#        'what kind of device you will use for reading e-book?',
#        'You feel comfortable while using this device [Computer ]',
#        'You feel comfortable while using this device [Smartphones]',
# ...

# %%
df=dataset.drop(columns="Timestamp",axis=1)

# %%
df.head()
# Out:
#   Gender    Age Community Type Occupation  \
# 0   Male  26-35          Urban    Student
# 1   Male  15-25          Urban    Student
# 2   Male  15-25          Urban    Student
# 3   Male  15-25       SubUrban    Student
# 4   Male  15-25          Urban    Student
#
#    What is your Educational Background? How frequently do you read the book?  \
# 0                        Postgraduation                           less often
# 1                        Postgraduation                    few times a month
# 2                       Undergraduation                    few times a month
# 3                        Postgraduation                           less often
# 4                       Undergraduation                                never
#
#   Do you read e-book? Which source do you prefer for reading?  \
# 0                  no                                   Print
# 1                 yes                                    Both
# ...

# %%
#Encoding startes

# %%
df.replace({'Male':1,'Female':2},inplace=True)

# %%
df.head()
# Out:
#    Gender    Age Community Type Occupation  \
# 0       1  26-35          Urban    Student
# 1       1  15-25          Urban    Student
# 2       1  15-25          Urban    Student
# 3       1  15-25       SubUrban    Student
# 4       1  15-25          Urban    Student
#
#    What is your Educational Background? How frequently do you read the book?  \
# 0                        Postgraduation                           less often
# 1                        Postgraduation                    few times a month
# 2                       Undergraduation                    few times a month
# 3                        Postgraduation                           less often
# 4                       Undergraduation                                never
#
#   Do you read e-book? Which source do you prefer for reading?  \
# 0                  no                                   Print
# 1                 yes                                    Both
# ...

# %%
#df.isnull().sum()

# %%
df['Do you read e-book?'].isnull().sum()
# Out:
# 0

# %%
df['Do you read e-book?'].replace({'yes':1,'no':0},inplace=True)

# %% [raw]
# df.head()

# %% [markdown]
# df['What attributes you prefer in the E-book [Flexibility]']=df['What attributes you prefer in the E-book [Flexibility]'].astype('category')
# #What attributes you prefer in the E-book [Availability]
# ##who influences to buy an e-book [individual decision]
# #What attributes you prefer in the E-book [Portability]
# #What attributes you prefer in the E-book [Affordability]
# #What attributes you prefer in the E-book [Storage]
#
# df['What attributes you prefer in the E-book [Flexibility]_cat']=df['What attributes you prefer in the E-book [Flexibility]'].cat.codes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 33 columns):
# Name                                                                                         145 non-null object
# Gender                                                                                       145 non-null int64
# Age                                                                                          145 non-null object
# Community Type                                                                               145 non-null object
# Occupation                                                                                   145 non-null object
#  What is your Educational Background?                                                        145 non-null object
# How frequently do you read the book?                                                         145 non-null object
# ...

# %%
df['What attributes you prefer in the E-book [Flexibility]'].value_counts()
df['What attributes you prefer in the E-book [Portability]'].value_counts()
#df['What attributes you prefer in the E-book [Flexibility]_cat'].value_counts()
# Out:
# agree                55
# Strongly agree       55
# neutral              31
# disagree              3
# Strongly disagree     1
# Name: What attributes you prefer in the E-book [Portability], dtype: int64

# %%
df['Community Type'].replace({'Urban':1,'SubUrban':2,'Rural':3},inplace=True)

# %%
df[' What is your Educational Background?'].replace({'Postgraduation':4,'Undergraduation':3,'High school':2,'Elementary':1},inplace=True)

# %%
encode=df[['From which source you prefer to read Fiction?','From which source you prefer to read Non-Fiction?','From which source you prefer to read The News?','From which source you prefer to read The Magazine?']]

# %%
pref_en=df[['what kind of device you will use for reading e-book?']]

# %%
pref_en[['pref_com','pref_sma','pref_tab','pref_E']]=pref_en['what kind of device you will use for reading e-book?'].str.split(",",expand=True)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\pandas\core\frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
pref_en.head()
# Out:
#   what kind of device you will use for reading e-book?     pref_com  \
# 0                                        Smartphones    Smartphones
# 1                              Computer, Smartphones       Computer
# 2                                        Smartphones    Smartphones
# 3                              Computer, Smartphones       Computer
# 4            Computer, Smartphones, Tablet, E-reader       Computer
#
#        pref_sma pref_tab     pref_E  com_pref sma_pref tab_pref
# 0          None     None       None         0        1        0
# 1   Smartphones     None       None         1        0        0
# 2          None     None       None         0        1        0
# 3   Smartphones     None       None         1        0        0
# 4   Smartphones   Tablet   E-reader         1        0        0

# %%
x=len(pref_en['pref_com'])

# %%
#pref_en['com_pref']=[]

for i in range (x):
    if pref_en['pref_com'][i]=='Computer':
        pref_en['com_pref'][i]=1
    else:
        pref_en['com_pref'][i]=0
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\HP\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3325: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
y=len(pref_en['pref_sma'])
#pref_en['sma_pref']

# %%
#df["C"] = ""
pref_en['sma_pref']=''
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for i in range (y):
    if pref_en['pref_sma'][i]=='Smartphones':
        pref_en['sma_pref'][i]=1
    elif pref_en['pref_com'][i]=='Smartphones':
        pref_en['sma_pref'][i]=1
    else:
        pref_en['sma_pref'][i]=0
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
pref_en['tab_pref']=''
z=len(pref_en['pref_tab'])
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in range (z):
    if pref_en['pref_com'][i]=='Tablet':
        pref_en['tab_pref'][i]=1
    elif pref_en['pref_sma'][i]=='Tablet':
        pref_en['tab_pref'][i]=1
    elif pref_en['pref_tab'][i]=='Tablet':
        pref_em['tab_pref'][i]=1
    else:
        pref_en['tab_pref'][i]=0
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
encode[['n_f_com','n_f_sma','n_f_tab','n_f_er']]=encode["From which source you prefer to read Non-Fiction?"].str.split(",",expand = True)
#encode.split(",")

# %%
encode[['f_com','f_sma','f_tab','f_er']]=encode["From which source you prefer to read Fiction?"].str.split(",",expand = True)

# %%
encode[['n_com','n_sma','n_tab','n_er']]=encode["From which source you prefer to read The News?"].str.split(",",expand = True)

# %%
encode[['m_com','m_sma','m_tab','m_er']]=encode["From which source you prefer to read The Magazine?"].str.split(",",expand = True)

# %%
encode.head()
# Out:
#   From which source you prefer to read Fiction?  \
# 0                                   Smartphones
# 1                         Computer, Smartphones
# 2                                        Tablet
# 3               Computer, Smartphones, E-reader
# 4                              Tablet, E-reader
#
#   From which source you prefer to read Non-Fiction?  \
# 0                             Computer, Smartphones
# 1                             Computer, Smartphones
# 2                                          E-reader
# 3                                          Computer
# 4           Computer, Smartphones, Tablet, E-reader
#
#   From which source you prefer to read The News?  \
# 0                          Computer, Smartphones
# 1                          Computer, Smartphones
# 2                                    Smartphones
# 3                                    Smartphones
# 4                  Smartphones, Tablet, E-reader
#
# ...

# %%
encode.drop(['From which source you prefer to read Fiction?','From which source you prefer to read Non-Fiction?','From which source you prefer to read The News?','From which source you prefer to read The Magazine?'], axis = 1, inplace = True)
#encode.drop(columns='From which source you prefer to read Fiction?','From which source you prefer to read Non-Fiction?','From which source you prefer to read The News?','From which source you prefer to read The Magazine?']],axis=1)

# %%
encode.head(9)
# Out:
#        n_f_com       n_f_sma  n_f_tab     n_f_er        f_com         f_sma  \
# 0     Computer   Smartphones     None       None  Smartphones          None
# 1     Computer   Smartphones     None       None     Computer   Smartphones
# 2     E-reader          None     None       None       Tablet          None
# 3     Computer          None     None       None     Computer   Smartphones
# 4     Computer   Smartphones   Tablet   E-reader       Tablet      E-reader
# 5  Smartphones      E-reader     None       None  Smartphones        Tablet
# 6     Computer      E-reader     None       None  Smartphones        Tablet
# 7  Smartphones          None     None       None  Smartphones          None
# 8     Computer          None     None       None     Computer          None
#
#        f_tab  f_er        n_com         n_sma      n_tab  n_er        m_com  \
# 0       None  None     Computer   Smartphones       None  None  Smartphones
# ...

# %% [markdown]
# encode['nf_com'] = np.where(encode['n_f_com']=='Computer', 1,0)

# %% [markdown]
# encode['nf_com'] = np.where(encode['n_f_com']=='Computer', 1,0)

# %% [markdown]
# #encode['nf_sma'] = ['1' if x == 'Smartphones'| else 'green' for x in df['Set']]
# #encode['value'] = np.select([encode.n_f_com =='Smartphones' , encode.n_f_sma =='Smartphones'], [encode.n_f_com, encode.n_f_sma])
# encode['nf_sma'] = [1 if x =='Smartphones' else 1 if y=='Smartphones' else 0 for x,y in zip(encode['n_f_com'],encode['n_f_sma'])]
# #encode['nf_sma'] = np.where(encode['n_f_com']=='Smartphones'|encode['n_f_sma']=='Smartphones', 1,0)

# %%
encode.to_excel('C:\\Users\\HP\\Desktop\\research paper\\Quesstionaire\\encode.xlsx',index=None)

# %% [markdown]
# li=[]
# for x,y in zip(encode['n_f_com'],encode['n_f_sma']):
#     if y=='Smartphones'or x=='Smartphones':
#         res=1
#     else:
#         res=0
#     li.append(res)

# %%
#li

# %% [markdown]
# for i in encode['n_f_com']:
#     if i=='Smartphones':
#         encode['n_f_sma']=encode['n_f_sma'].replace({'None':'Smartphones'})
#     else:
#         encode['n_f_sma']=0
# #encode['n_f_sma'] = np.where(encode['n_f_com'] == "Smartphones", encode['Action'], df['Target'])

# %% [markdown]
# encode['n_f_com'].unique()

# %%
df['You feel comfortable while using this device [Computer ]'].replace({'Strongly agree':'strongly agree','Disagree':'disagree'},inplace=True)
df['You feel comfortable while using this device [Smartphones]'].replace({'Strongly agree':'strongly agree','Disagree':'disagree'},inplace=True)
df['You feel comfortable while using this device [Tablet]'].replace({'Strongly agree':'strongly agree','Disagree':'disagree'},inplace=True)
df['You feel comfortable while using this device [E-reader]'].replace({'Strongly agree':'strongly agree','Disagree':'disagree'},inplace=True)

df['What attributes you prefer in the E-book [Flexibility]'].replace({'Strongly agree':'strongly agree','Strongly disagree':'strongly disagree'},inplace=True)
df['What attributes you prefer in the E-book [Portability]'].replace({'Strongly agree':'strongly agree','Strongly disagree':'strongly disagree'},inplace=True)
df['What attributes you prefer in the E-book [Affordability]'].replace({'Strongly agree':'strongly agree','Strongly disagree':'strongly disagree'},inplace=True)
df['What attributes you prefer in the E-book [Storage]'].replace({'Strongly agree':'strongly agree','Strongly disagree':'strongly disagree'},inplace=True)
df['What attributes you prefer in the E-book [Availability]'].replace({'Strongly agree':'strongly agree','Strongly disagree':'strongly disagree'},inplace=True)

# %%
df['who influences to buy an e-book [individual decision]'].replace({'strongly agree':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)
df['who influences to buy an e-book [friends]'].replace({'strongly agree':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)
df['who influences to buy an e-book [relatives]'].replace({'strongly agree':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)
df['who influences to buy an e-book [advertisements]'].replace({'strongly agree':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)
df['which category you falls under [lazy]'].replace({'strongly agree':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)
df['which category you falls under [active]'].replace({'strongly agree':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)
df['which category you falls under [proactive]'].replace({'strongly agree':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)
#######df['How likely do you prefer using e-book ?'].replace({'Strongly agree':5,'agree':4,'neutral':3,'disagree':2,'Strongly disagree':1},inplace=True)
df['You feel comfortable while using this device [Computer ]'].replace({'strongly agree':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)
df['You feel comfortable while using this device [Smartphones]'].replace({'strongly agree':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)
df['You feel comfortable while using this device [Tablet]'].replace({'strongly agree':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)
df['You feel comfortable while using this device [E-reader]'].replace({'strongly agree':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)

# %%
df['What attributes you prefer in the E-book [Flexibility]'].replace({'strongly agree':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)

df['What attributes you prefer in the E-book [Portability]'].replace({'strongly agree':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)

df['What attributes you prefer in the E-book [Affordability]'].replace({'strongly agree':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)

df['What attributes you prefer in the E-book [Storage]'].replace({'strongly agree':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)

df['What attributes you prefer in the E-book [Availability]'].replace({'strongly agree':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)

# %%
df['How frequently do you read the book?'].replace({'almost every day':5,'few times a week':4,'few times a month':3,'less often':2,'never':1},inplace=True)
df['Do you think availability of internet is the reason behind the growth of usage of E-book?'].replace({'yes':1,'no':0},inplace=True)
df['Occupation'].replace({'Student':1,'Employee':2,'Business':3,'Doctor':4},inplace=True)
df['Which source do you prefer for reading?'].replace({'Print':1,'E-book':2,'Both':3},inplace=True)

#df['what kind of device you will use for reading e-book?'].replace({'Computer':5,'agree':4,'neutral':3,'disagree':2,'strongly disagree':1},inplace=True)

# %%
df['How likely do you prefer using e-book ?'].replace({'To a Great Extent':4,'Somewhat':3,'Very Little':2,'Not at All':1},inplace=True)

# %%
df['How frequently do you read the book?'].replace({'almost every day':5,'few times a week':4,'few times a month':3,'less often':2,'never':1},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 29 columns):
# Name                                                                                         145 non-null object
# Gender                                                                                       145 non-null int64
# Age                                                                                          145 non-null object
# Community Type                                                                               145 non-null int64
# Occupation                                                                                   145 non-null int64
#  What is your Educational Background?                                                        145 non-null int64
# How frequently do you read the book?                                                         145 non-null object
# ...

# %%
who influences to buy an e-book [individual decision]
who influences to buy an e-book [friends]
who influences to buy an e-book [relatives]
who influences to buy an e-book [advertisements]
which category you falls under [lazy]
which category you falls under [active]
which category you falls under [proactive]
Do you think availability of internet is the reason behind the growth of usage of E-book?
How likely do you prefer using e-book ?
what kind of device you will use for reading e-book?
You feel comfortable while using this device [Computer ]
You feel comfortable while using this device [Smartphones]
You feel comfortable while using this device [Tablet]
You feel comfortable while using this device [E-reader]

# %%
data=pd.read_excel("C:\\Users\\HP\\Desktop\\research paper\\Quesstionaire\\encoded data for multiple choice questions.xlsx")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 16 columns):
# nf_com    146 non-null int64
# nf_sma    146 non-null int64
# nf_tab    146 non-null int64
# nf_er     146 non-null int64
# f_com     146 non-null int64
# f_sma     146 non-null int64
# f_tab     146 non-null int64
# f_er      146 non-null int64
# n_com     146 non-null int64
# n_sma     146 non-null int64
# n_tab     146 non-null int64
# n_er      146 non-null int64
# m_com     146 non-null int64
# m_sma     146 non-null int64
# m_tab     146 non-null int64
# m_er      146 non-null int64
# dtypes: int64(16)
# memory usage: 18.3 KB

# %%
dfy=df.drop(['From which source you prefer to read Fiction?','From which source you prefer to read Non-Fiction?','From which source you prefer to read The News?','From which source you prefer to read The Magazine?'], axis = 1, inplace = True)

# %%
final = pd.concat([df, data], axis=1)

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 45 columns):
# Name                                                                                         145 non-null object
# Gender                                                                                       145 non-null float64
# Age                                                                                          145 non-null object
# Community Type                                                                               145 non-null float64
# Occupation                                                                                   145 non-null float64
#  What is your Educational Background?                                                        145 non-null float64
# How frequently do you read the book?                                                         145 non-null object
# ...

# %%
How frequently do you read the book?
Do you think availability of internet is the reason behind the growth of usage of E-book?
Occupation
Which source do you prefer for reading?
How likely do you prefer using e-book ?
what kind of device you will use for reading e-book?

# %%
df.to_csv('C:\\Users\\HP\\Desktop\\research paper\\Quesstionaire\\MM1921438_G.V.S.R.M.SUHASH.csv',index=None)

# %%
final.to_excel('C:\\Users\\HP\\Desktop\\research paper\\Quesstionaire\\survey_data1.xlsx',index=None)

# %%
survey_data=df

# %%
survey_data.describe()
# Out:
#            Gender  Do you read e-book?  \
# count  145.000000           145.000000
# mean     1.406897             0.641379
# std      0.492958             0.481258
# min      1.000000             0.000000
# 25%      1.000000             0.000000
# 50%      1.000000             1.000000
# 75%      2.000000             1.000000
# max      2.000000             1.000000
#
#        who influences to buy an e-book [individual decision]  \
# count                                         145.000000
# mean                                            3.889655
# std                                             1.106278
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        who influences to buy an e-book [friends]  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 29 columns):
# Name                                                                                         145 non-null object
# Gender                                                                                       145 non-null int64
# Age                                                                                          145 non-null object
# Community Type                                                                               145 non-null int64
# Occupation                                                                                   145 non-null object
#  What is your Educational Background?                                                        145 non-null int64
# How frequently do you read the book?                                                         145 non-null object
# ...

# %%
df['Community Type'].value_counts()
# Out:
# Urban       85
# SubUrban    33
# Rural       27
# Name: Community Type, dtype: int64

# %%
df['Occupation'].value_counts()
# Out:
# Student     109
# Employee     30
# Business      5
# Doctor        1
# Name: Occupation, dtype: int64

# %%
df[' What is your Educational Background?'].value_counts()/len(df[' What is your Educational Background?'])*100
# Out:
# 3    53.793103
# 4    42.068966
# 2     3.448276
# 1     0.689655
# Name:  What is your Educational Background?, dtype: float64

# %%
df['How frequently do you read the book?'].value_counts()
# Out:
# few times a week     47
# less often           36
# few times a month    29
# almost every day     26
# never                 7
# Name: How frequently do you read the book?, dtype: int64
